# %%
# !pip install -r requirements.txt

# python must be <3.10. Python 3.9.6 is ok, otherwise torch wont work
# Out:
# Requirement already satisfied: xarray==0.14.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: torch==1.13.1 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (3.9.0)
# Requirement already satisfied: numpy==1.23 in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.23.0)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: pandas>=0.24 in ./.venv/lib/python3.9/site-packages (from xarray==0.14.1->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from torch==1.13.1->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 4)) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 4)) (3.19.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas>=0.24->xarray==0.14.1->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas>=0.24->xarray==0.14.1->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 4)) (1.16.0)
#
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
#import sys
import os

#import torch
#import torch.nn as nn
#from torch.nn import functional as F
#from torch.autograd import Variable

#import numpy as np
#import pandas as pd
#import random
import matplotlib.pyplot as plt
import seaborn as sns
#import copy

import warnings

warnings.filterwarnings('ignore')

# %%
from src.cddm.utils import *
from src.cddm.continual_learning import continual_learning
from src.cddm.models import GRU

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
else:
    device = torch.device('cpu')

# %% [markdown]
# # Hyperparameters initialization

# %%
problem = 'plasticity-rve'
model_name = 'gru'
data_folder = 'data/rve'
result_folder = 'result'
    
SAVE_MODELS = False
SAVE_DATA = True
 
input_size = 3        # three strain components
output_size = 3       # three stress components
seq_len = 101         # number of pseudo-time steps : 0-100
hidden_size = 128     # number of hidden states for GRU
num_layers = 2        # number of GRU cells 

optimizer_name = 'Adam'
lr = 0.01
weight_decay = 1e-6
n_epochs = 1000
alpha = 0.95          # pruning parameter

seed = 0

tasks = ['B', 'C', 'A']      # sequence of tasks (with order)

    
if problem == 'plasticity-plates':
    file_names = [f'{data_folder}/{task}.pkl' for task in tasks]
else:
    file_names = [f'{data_folder}/{task}.pickle' for task in tasks]
        
num_tasks = len(file_names)
 
num_val = 100                      # number of validation paths for every task
num_test = 100                     # number of test paths for every task
nums_train = [800, 100, 100]       # number of training paths for every task; len(nums_train) == num_tasks

set_seed(seed)

# %% [markdown]
# # Network initialization

# %%
# Initialize the network (GRU)

net = GRU(input_size=input_size, seq_len=seq_len, hidden_size=hidden_size, 
          num_layers=num_layers, output_size=output_size, device=device).to(device)

# %%
# Creating directories and path to save results

if not os.path.exists(result_folder):
            os.mkdir(result_folder)

if SAVE_MODELS:
    dict_names = {}
    case_name = f'{problem}_'
    for i, task in enumerate(tasks):
        case_name += f'{task}-'

    case_name = case_name[:-1] 
    path_to_save = f"{model_name}_{case_name}_seed{seed}_num-layers{num_layers}_hidden{hidden_size}_lr{lr}_alpha{alpha}.pth"
else:
    path_to_save = f"model.pth"

# %% [markdown]
# # Training and evaluation

# %%
# Training the model on the given sequence of tasks

print(f">>>>>>>>>>>>>>>>>>>{nums_train} TRAINING POINTS<<<<<<<<<<<<<<<<<<<<")           
                           
net = continual_learning(net, 
                         file_names=file_names, alpha=alpha, 
                         optimizer_name=optimizer_name, scheduler=None,
                         n_epochs=n_epochs, lr=lr, weight_decay=weight_decay, 
                         device=device, 
                         nums_train=nums_train,
                         num_val=num_val,
                         num_test=num_test,
                         seed=seed,
                         path_to_save=path_to_save,
                         result_folder=result_folder,
                         problem=problem)
# Out:
# >>>>>>>>>>>>>>>>>>>[800, 100, 100] TRAINING POINTS<<<<<<<<<<<<<<<<<<<<
# ['data/rve/B.pickle', 'data/rve/C.pickle', 'data/rve/A.pickle']
# TRAIN PATHS:  800
# --------------TASK 1---------------------
# epoch: 0, Train Loss: 6.506e-01, Val Loss: 4.062e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Training the model on the given sequence of tasks
#       3 print(f">>>>>>>>>>>>>>>>>>>{nums_train} TRAINING POINTS<<<<<<<<<<<<<<<<<<<<")
# ----> 5 net = continual_learning(net,
#       6                          file_names=file_names, alpha=alpha,
#       7                          optimizer_name=optimizer_name, scheduler=None,
#       8                          n_epochs=n_epochs, lr=lr, weight_decay=weight_decay,
#       9                          device=device,
#      10                          nums_train=nums_train,
#      11                          num_val=num_val,
#      12                          num_test=num_test,
#      13                          seed=seed,
#      14                          path_to_save=path_to_save,
#      15                          result_folder=result_folder,
#      16                          problem=problem)
#
# File ~/Desktop/Continual Learning/CDDM/src/cddm/continual_learning.py:125, in continual_learning(net, file_names, alpha, optimizer_name, scheduler, n_epochs, lr, weight_decay, device, nums_train, num_val, num_test, SCALE, seed, path_to_save, result_folder, problem)
#     122 net.set_task(task_id)
#     123 net.set_trainable_masks(task_id)
# --> 125 net = train(net=net,
#     126             x_train=x_train, y_train=y_train,
#     127             x_val=x_val, y_val=y_val,
#     128             device=device,
#     129             lr=lr, n_epochs=n_epochs,
#     130             optimizer=optimizer, scheduler=scheduler,
#     131             task_id=task_id,
#     132             path_to_save=path_to_save)
#     134 net.load_state_dict(torch.load(f"{result_folder}/{path_to_save}"))
#     136 net.eval()
#
# File ~/Desktop/Continual Learning/CDDM/src/cddm/train.py:119, in train(net, x_train, y_train, x_val, y_val, device, lr, n_epochs, optimizer, scheduler, task_id, batch_size, path_to_save, result_folder, print_every)
#     117 loss_train = running_loss_train / num_train
#     118 net.eval()
# --> 119 y_val_pred = net(x_val.to(device))
#     120 loss_val = loss_func(y_val, y_val_pred)
#     122 if scheduler is not None:
#
# File ~/Desktop/Continual Learning/CDDM/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/Continual Learning/CDDM/src/cddm/models.py:371, in GRU.forward(self, input, hx)
#     369         hidden_l = self.rnn_cell_list[layer](input[:, t, :], hidden[layer])
#     370     else:
# --> 371         hidden_l = self.rnn_cell_list[layer](hidden[layer - 1], hidden[layer])
#     373     hidden[layer] = hidden_l
#     375 outs.append(hidden_l)
#
# File ~/Desktop/Continual Learning/CDDM/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/Continual Learning/CDDM/src/cddm/models.py:121, in GRUCell.forward(self, input, hx, mode, alpha)
#     119 h2h_active_weight = self.h2h.weight*self.tasks_masks[self.task_id][f'rnn_cell_list.{self.num_layer}.h2h.weight'].to(self.device)
#     120 h2h_active_bias = self.h2h.bias*self.tasks_masks[self.task_id][f'rnn_cell_list.{self.num_layer}.h2h.bias'].to(self.device)
# --> 121 h_t = F.linear(hx, weight=h2h_active_weight, bias=h2h_active_bias)
#     123 x_reset, x_upd, x_new = x_t.chunk(3, 1)
#     124 h_reset, h_upd, h_new = h_t.chunk(3, 1)
#
# KeyboardInterrupt:

# %%
# Evaluation of the model

all_losses = {}
all_errors = {}

losses, errors = eval(net, file_names, nums_train=nums_train, num_val=num_val, num_test=num_test, problem=problem)         
    
for i in range(len(nums_train)):
    all_losses[f"{tasks[i]}_{nums_train[i]}points"] = losses[i]
    all_errors[f"{tasks[i]}_{nums_train[i]}points"] = errors[i]

    
df_losses = pd.DataFrame([all_losses])
df_errors = pd.DataFrame([all_errors])
    
print(df_errors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       3 all_losses = {}
#       4 all_errors = {}
# ----> 6 losses, errors = eval(net, file_names, nums_train=nums_train, num_val=num_val, num_test=num_test, problem=problem)
#       8 for i in range(len(nums_train)):
#       9     all_losses[f"{tasks[i]}_{nums_train[i]}points"] = losses[i]
#
# File ~/Desktop/Continual Learning/CDDM/src/cddm/utils.py:274, in eval(net, file_names, nums_train, num_val, num_test, idx_min, idx_max, dim, problem)
#     246 """ The function prints losses and relative errors for every task.
#     247
#     248 Parameters
#    (...)
#     268     Error on every task.
#     269 """
#     271 num_tasks = len(file_names)
# --> 274 net.eval()
#     276 losses = []
#     277 errors = []
#
# AttributeError: 'NoneType' object has no attribute 'eval'

# %% [markdown]
# # Saving results

# %%
if SAVE_DATA:
    if not os.path.exists(result_folder):
        os.mkdir(result_folder)
            
    dict_names = {}
    case_name = f'{problem}_'
    for i, task in enumerate(tasks):
        dict_names[i] = f'{task}'
        case_name += f'{task}-'

    case_name = case_name[:-1]    
    df_errors.rename(index = dict_names, inplace = True)
        
    if len(tasks) > 1:
        df_errors.to_csv(f"{result_folder}/{case_name}_error_seed{seed}_num-layers{num_layers}_hidden{hidden_size}_lr{lr}_alpha{alpha}.csv", index=False)
    else:
        df_errors.to_csv(f"{result_folder}/{case_name}_error_seed{seed}_num-layers{num_layers}_hidden{hidden_size}_lr{lr}.csv", index=False)
            
if os.path.exists(f"{result_folder}/model.pth"):
     os.remove(f"{result_folder}/model.pth") 
            
    
if os.path.exists(f"{result_folder}/masks_model.pth"):
      os.remove(f"{result_folder}/masks_model.pth")

# %% [markdown]
# # Plotting predictions

# %%
x_tests = []
y_tests = []
y_preds = []

for task_id in range(len(tasks)):
    x_train, y_train, x_val, y_val, x_test, y_test, x_mean, x_std, y_mean, y_std = process_data(file_names[task_id], 
                                                                                                num_train=nums_train[task_id], 
                                                                                                num_val=num_val, 
                                                                                                num_test=num_test
                                                                                                )

    net.set_task(task_id)
    y_pred = net(x_test).detach()
    
    x_tests.append( (x_test * x_std + x_mean).cpu().numpy() )
    y_tests.append( (y_test * y_std + y_mean).cpu().numpy() )
    y_preds.append( (y_pred * y_std + y_mean).cpu().numpy() )

# %%
colors  = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:gray']
sample = 35

# %%
sns.set_style("whitegrid")

xticks = [i for i in range(0, seq_len, 10)]

sigma = [r'$\sigma_{11}$', r'$\sigma_{22}$', r'$\sigma_{12}$']

fig, ax = plt.subplots(len(sigma), 1)
fig.set_size_inches(12, 16)

time = [i for i in range(101)]
for i in range(len(sigma)):

    for task_id in range(num_tasks):
        ax[i].plot(time, y_tests[task_id][sample][:, i], 
                linewidth=2, markersize=5, color = colors[task_id])

    for task_id in range(num_tasks):
        ax[i].errorbar(time[::5], y_preds[task_id][sample][:, i][::5], 
                    fmt='o', linewidth=1, markersize=10, color = colors[task_id])
        
    component = sigma[i]

    ax[i].set_ylabel('Stress (MPa)', fontsize=22)
    ax[i].set_xlabel('Time step', fontsize=22)
    ax[i].set_title(component, fontsize=24)
    ax[i].xaxis.set_tick_params(labelsize=22)
    ax[i].yaxis.set_tick_params(labelsize=22)


legend =  [f'test: Task {tasks[task_id]}' for task_id in range(num_tasks)] + [f'CDDM: Task {tasks[task_id]}' for task_id in range(num_tasks)]
fig.legend(legend, fontsize=22, loc='lower center', ncol=2)

fig.suptitle(fr'{tasks[0]} ({nums_train[0]} paths) $\to$ {tasks[1]} ({nums_train[1]} paths) $\to$ {tasks[2]} ({nums_train[2]} paths)', fontsize=22, y=0.95)
plt.subplots_adjust(left=0.1,
                    bottom=0.2, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.45)

#plt.savefig(f'rve_{case_name}_sigma_800-{num_train}points.pdf')
plt.show()
